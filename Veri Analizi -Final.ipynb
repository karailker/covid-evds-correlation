# %% [markdown]
# # Gerekli Modüllerin eklenmesi

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from evds import evdsAPI
import datetime

# %% [markdown]
# # Bugüne kadar olan verilerin alınabilmesi için dün ve bugünün datetime objesi olarak oluşturulması

# %%
today_raw = datetime.datetime.now()
today = today_raw.strftime("%d-%m-%Y")

yesterday = today_raw - datetime.timedelta(days = 1)

# %% [markdown]
# # Merkez Bankası Elektronik Veri Dağıtım Sistemi (EVDS) verilerinin çekilmesi

# %%
def get_cbrt_data(cbrt_series):

    evds = evdsAPI('YOUR-EVDS-API')

    evds_series = cbrt_series

    start_date = "11-03-2020"

    end_date = yesterday.strftime("%d-%m-%Y")

    end_month = yesterday.strftime("%Y-%m")

    # print(end_month)

    temp_cbrt_data = evds.get_data(evds_series,
    startdate=start_date,
    enddate=end_date,
    #formulas=[0,0,0],
    )

    return temp_cbrt_data

# %% [markdown]
# ### Günlük Veriler

# %%
daily_series = ["TP.DK.USD.S.YTL", "TP.DK.EUR.S.YTL", "TP.MK.F.BILESIK", "TP.BISTTLREF.ORAN"]
daily_data = get_cbrt_data(daily_series)

daily_data['Tarih'] = pd.to_datetime(daily_data['Tarih'], format="%d-%m-%Y")
daily_data = daily_data.reset_index()
daily_data = daily_data.drop(["index"], axis=1)
# daily_data = daily_data.fillna(method='ffill') #For filling NaN rows with previous values
daily_data.set_index('Tarih', inplace=True)

daily_data.rename(columns={'TP_DK_USD_S_YTL':'Dolar/TL', "TP_DK_EUR_S_YTL":"Euro/TL","TP_MK_F_BILESIK":"BIST100Kapanis", "TP_BISTTLREF_ORAN":"TLGecelikReferansFaizi"}, inplace=True)

daily_data.loc["2020-07-27":]["BIST100Kapanis"] = daily_data.loc["2020-07-27":]["BIST100Kapanis"] * 100 # 27 Haziran 2020 Tarihinde BIST Endekslerinden İki Sıfır Atılmıştır

daily_data
# Out:
# D:\Anaconda3\envs\newenv\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#             Dolar/TL  Euro/TL  BIST100Kapanis  TLGecelikReferansFaizi
# Tarih
# 2020-03-11    6.1261   6.9580       100966.27                 10.9831
# 2020-03-12    6.1613   6.9795        93639.50                 10.8384
# 2020-03-13    6.2376   7.0265        95605.22                 10.7272
# 2020-03-16    6.2824   7.0226        87888.34                 10.7680
# 2020-03-17    6.3743   7.1271        86777.69                 10.6449
# ...              ...      ...             ...                     ...
# 2020-08-26    7.3807   8.7237       109902.00                  9.7515
# 2020-08-27    7.3591   8.6911       110893.00                  9.7500
# 2020-08-28    7.3306   8.6677       110055.00                  9.7706
# 2020-08-31    7.3182   8.7054       107861.00                  9.7635
# 2020-09-01    7.3393   8.7441       108519.00                  9.7455
#
# [125 rows x 4 columns]

# %% [markdown]
# ### Haftalık Veriler

# %%
weekly_series = ["TP.AB.C1", "TP.KKHARTUT.KT1", "TP.KREDI.L001"]
weekly_data = get_cbrt_data(weekly_series)

weekly_data['Tarih'] = pd.to_datetime(weekly_data['Tarih'], format="%d-%m-%Y")
weekly_data = weekly_data.reset_index()
weekly_data = weekly_data.drop(["index"], axis=1)
weekly_data = weekly_data.fillna(method='ffill') #For filling NaN rows with previous values
weekly_data.set_index('Tarih', inplace=True)

weekly_data.rename(columns={'TP_AB_C1':'AltinRezervi',"TP_KKHARTUT_KT1":"KartHarcamaTutari", "TP_KREDI_L001":"HaftalikKredi"}, inplace=True)

weekly_data
# Out:
#            YEARWEEK  AltinRezervi  KartHarcamaTutari  HaftalikKredi
# Tarih
# 2020-03-13  2020-11       31690.0         21272308.0   2.708517e+09
# 2020-03-20  2020-12       28304.0         19568916.0   2.749744e+09
# 2020-03-27  2020-13       31325.0         13497929.0   2.768395e+09
# 2020-04-03  2020-14       31306.0         14123457.0   2.807290e+09
# 2020-04-10  2020-15       32871.0         13488741.0   2.833365e+09
# 2020-04-17  2020-16       33958.0         15236343.0   2.899083e+09
# 2020-04-24  2020-17       33785.0         12965924.0   2.954655e+09
# 2020-05-01  2020-18       34785.0         15262968.0   2.998581e+09
# 2020-05-08  2020-19       34683.0         16558922.0   3.047473e+09
# 2020-05-15  2020-20       35535.0         17296531.0   3.036171e+09
# 2020-05-22  2020-21       36812.0         16672019.0   3.028738e+09
# 2020-05-29  2020-22       36666.0         14364906.0   3.052802e+09
# 2020-06-05  2020-23       36610.0         19348983.0   3.067307e+09
# 2020-06-12  2020-24       37579.0         20087612.0   3.097536e+09
# 2020-06-19  2020-25       38371.0         21188045.0   3.114677e+09
# 2020-06-26  2020-26       38821.0         20137021.0   3.141043e+09
# 2020-07-03  2020-27       39159.0         20908448.0   3.150704e+09
# 2020-07-10  2020-28       40425.0         21585208.0   3.175933e+09
# 2020-07-17  2020-29       40229.0         22525159.0   3.192771e+09
# 2020-07-24  2020-30       42104.0         23232308.0   3.218614e+09
# 2020-07-31  2020-31       43572.0         24408730.0   3.264349e+09
# 2020-08-07  2020-32       45229.0         19909368.0   3.318260e+09
# 2020-08-14  2020-33       42816.0         22132716.0   3.346658e+09
# 2020-08-21  2020-34       43277.0         23233181.0   3.336932e+09

# %% [markdown]
# ### Aylık Veriler (Haftalık veri türüne dönüştürüldü)

# %%
monthly_series = ["TP.TIG04", "TP.ODEMGZS.GTOPLAM", "TP.FG.J0", "TP.KB.GID001", "TP.AKONUTSAT1.TOPLAM"]
monthly_data = get_cbrt_data(monthly_series)

monthly_data = monthly_data.append(pd.Series({"Tarih":"2020-8"},name='5')) #7. Ayı da kullanabilmek için manuel olarak 8. Ay satırını eklemek gerekiyor
# monthly_data = monthly_data.append(pd.Series({"Tarih":"2020-9"},name='6'))

monthly_data['Tarih'] = pd.to_datetime(monthly_data['Tarih'], format="%Y-%m")
monthly_data = monthly_data.reset_index()
monthly_data = monthly_data.drop(["index"], axis=1)
monthly_data = monthly_data.fillna(method='ffill') #For filling NaN rows with previous values
monthly_data.set_index('Tarih', inplace=True)

monthly_data.rename(columns={'TP_TIG04':'IssizSayisi',"TP_ODEMGZS_GTOPLAM":"ZiyaretciSayisi", "TP_FG_J0":"TUFE", "TP_KB_GID001":"MerkeziYonetimButceGideri", "TP_AKONUTSAT1_TOPLAM":"KonutSatisi"}, inplace=True)

monthly_data_resampled = monthly_data.asfreq(freq='MS', method='ffill', how="first")

monthly_data_resampled = monthly_data_resampled.asfreq(freq='W-FRI', method='ffill')
monthly_data_resampled /= monthly_data_resampled.groupby(monthly_data_resampled.index.strftime('%Y-%m-%d')).transform('count')
monthly_data_resampled = monthly_data_resampled.loc["2020-03-13":]

monthly_data_resampled
# Out:
#             IssizSayisi  ZiyaretciSayisi    TUFE  MerkeziYonetimButceGideri  \
# Tarih
# 2020-03-13       3971.0         906067.0  450.58                 91161877.0
# 2020-03-20       3971.0         906067.0  450.58                 91161877.0
# 2020-03-27       3971.0         906067.0  450.58                 91161877.0
# 2020-04-03       3775.0          50630.0  454.43                108443227.0
# 2020-04-10       3775.0          50630.0  454.43                108443227.0
# 2020-04-17       3775.0          50630.0  454.43                108443227.0
# 2020-04-24       3775.0          50630.0  454.43                108443227.0
# 2020-05-01       3826.0          51588.0  460.62                 85446203.0
# 2020-05-08       3826.0          51588.0  460.62                 85446203.0
# 2020-05-15       3826.0          51588.0  460.62                 85446203.0
# 2020-05-22       3826.0          51588.0  460.62                 85446203.0
# 2020-05-29       3826.0          51588.0  460.62                 85446203.0
# 2020-06-05       3826.0         128861.0  465.84                 85642670.0
# 2020-06-12       3826.0         128861.0  465.84                 85642670.0
# 2020-06-19       3826.0         128861.0  465.84                 85642670.0
# 2020-06-26       3826.0         128861.0  465.84                 85642670.0
# 2020-07-03       3826.0         128861.0  468.56                116225366.0
# 2020-07-10       3826.0         128861.0  468.56                116225366.0
# 2020-07-17       3826.0         128861.0  468.56                116225366.0
# 2020-07-24       3826.0         128861.0  468.56                116225366.0
# 2020-07-31       3826.0         128861.0  468.56                116225366.0
#
#             KonutSatisi
# Tarih
# 2020-03-13     108670.0
# 2020-03-20     108670.0
# 2020-03-27     108670.0
# 2020-04-03      42783.0
# 2020-04-10      42783.0
# 2020-04-17      42783.0
# 2020-04-24      42783.0
# 2020-05-01      50936.0
# 2020-05-08      50936.0
# 2020-05-15      50936.0
# 2020-05-22      50936.0
# 2020-05-29      50936.0
# 2020-06-05     190012.0
# 2020-06-12     190012.0
# 2020-06-19     190012.0
# 2020-06-26     190012.0
# 2020-07-03     229357.0
# 2020-07-10     229357.0
# 2020-07-17     229357.0
# 2020-07-24     229357.0
# 2020-07-31     229357.0

# %% [markdown]
# # Covid-19 Verilerinin Çekilmesi (Kaynak: John Hopkins University - Github)

# %%
path = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
covid_data = pd.read_csv(path,index_col=False)

covid_data = covid_data.drop(["Province/State","Lat","Long"], axis=1)
covid_data.set_index("Country/Region",inplace =True)
covid_data = covid_data.stack()
covid_data = covid_data.reset_index()
covid_data.rename(columns={'level_1':'Tarih',0:"VakaSayisi"}, inplace=True)
covid_data['Tarih'] = pd.to_datetime(covid_data['Tarih'])
covid_data = covid_data[(covid_data['Country/Region']=='Turkey') & (covid_data['Tarih']>'2020-03-10')]
covid_data = covid_data.reset_index()
covid_data = covid_data.drop(["index"], axis=1)
covid_data = covid_data.drop(['Country/Region'], axis=1)
covid_data.set_index("Tarih",inplace =True)

covid_data
# Out:
#             VakaSayisi
# Tarih
# 2020-03-11           1
# 2020-03-12           1
# 2020-03-13           5
# 2020-03-14           5
# 2020-03-15           6
# ...                ...
# 2020-08-28      265515
# 2020-08-29      267064
# 2020-08-30      268546
# 2020-08-31      270133
# 2020-09-01      271705
#
# [175 rows x 1 columns]

# %% [markdown]
# ### Günlük Covid Verilerinin ikinci bir değişkene kopyalanması

# %%
daily_covid_data = covid_data
daily_covid_data
#covid_data = covid_data.resample('1M').mean() #monthly
# Out:
#             VakaSayisi
# Tarih
# 2020-03-11           1
# 2020-03-12           1
# 2020-03-13           5
# 2020-03-14           5
# 2020-03-15           6
# ...                ...
# 2020-08-28      265515
# 2020-08-29      267064
# 2020-08-30      268546
# 2020-08-31      270133
# 2020-09-01      271705
#
# [175 rows x 1 columns]

# %% [markdown]
# ### Haftalık Covid Verilerinin Günlük Verilerden türetilmesi

# %%
weekly_covid_data = covid_data.resample('W-FRI').mean() #weekly
weekly_covid_data
# Out:
#                VakaSayisi
# Tarih
# 2020-03-13       2.333333
# 2020-03-20     103.571429
# 2020-03-27    2438.142857
# 2020-04-03   13673.142857
# 2020-04-10   34695.142857
# 2020-04-17   65344.857143
# 2020-04-24   94368.857143
# 2020-05-01  115000.285714
# 2020-05-08  129800.571429
# 2020-05-15  141619.714286
# 2020-05-22  151477.857143
# 2020-05-29  158855.000000
# 2020-06-05  165648.714286
# 2020-06-12  172123.142857
# 2020-06-19  181149.714286
# 2020-06-26  190360.428571
# 2020-07-03  199782.714286
# 2020-07-10  207853.428571
# 2020-07-17  214940.000000
# 2020-07-24  221485.571429
# 2020-07-31  227994.571429
# 2020-08-07  235048.142857
# 2020-08-14  243213.000000
# 2020-08-21  251874.857143
# 2020-08-28  261169.571429
# 2020-09-04  269362.000000

# %% [markdown]
# # Günlük Covid ve EVDS Verilerinin birleştirilmesi

# %%
daily_merged_data = pd.concat([daily_covid_data, daily_data[daily_data.columns[0:]]], axis=1)
daily_merged_data = daily_merged_data.fillna(method='ffill') #For filling NaN rows with previous values
daily_merged_data
# Out:
#             VakaSayisi  Dolar/TL  Euro/TL  BIST100Kapanis  \
# Tarih
# 2020-03-11           1    6.1261   6.9580       100966.27
# 2020-03-12           1    6.1613   6.9795        93639.50
# 2020-03-13           5    6.2376   7.0265        95605.22
# 2020-03-14           5    6.2376   7.0265        95605.22
# 2020-03-15           6    6.2376   7.0265        95605.22
# ...                ...       ...      ...             ...
# 2020-08-28      265515    7.3306   8.6677       110055.00
# 2020-08-29      267064    7.3306   8.6677       110055.00
# 2020-08-30      268546    7.3306   8.6677       110055.00
# 2020-08-31      270133    7.3182   8.7054       107861.00
# 2020-09-01      271705    7.3393   8.7441       108519.00
#
#             TLGecelikReferansFaizi
# Tarih
# 2020-03-11                 10.9831
# 2020-03-12                 10.8384
# 2020-03-13                 10.7272
# 2020-03-14                 10.7272
# 2020-03-15                 10.7272
# ...                            ...
# 2020-08-28                  9.7706
# 2020-08-29                  9.7706
# 2020-08-30                  9.7706
# 2020-08-31                  9.7635
# 2020-09-01                  9.7455
#
# [175 rows x 5 columns]

# %% [markdown]
# ## Haftalık Covid ve EVDS Verilerinin birleştirilmesi

# %%
weekly_merged_data = pd.concat([weekly_covid_data, weekly_data[weekly_data.columns[1:]]], axis=1)

weekly_merged_data = pd.concat([weekly_merged_data, monthly_data_resampled[monthly_data_resampled.columns[1:]]], axis=1)
weekly_merged_data = weekly_merged_data.loc[:"2020-07-31"]

weekly_merged_data
# Out:
#                VakaSayisi  AltinRezervi  KartHarcamaTutari  HaftalikKredi  \
# Tarih
# 2020-03-13       2.333333       31690.0         21272308.0   2.708517e+09
# 2020-03-20     103.571429       28304.0         19568916.0   2.749744e+09
# 2020-03-27    2438.142857       31325.0         13497929.0   2.768395e+09
# 2020-04-03   13673.142857       31306.0         14123457.0   2.807290e+09
# 2020-04-10   34695.142857       32871.0         13488741.0   2.833365e+09
# 2020-04-17   65344.857143       33958.0         15236343.0   2.899083e+09
# 2020-04-24   94368.857143       33785.0         12965924.0   2.954655e+09
# 2020-05-01  115000.285714       34785.0         15262968.0   2.998581e+09
# 2020-05-08  129800.571429       34683.0         16558922.0   3.047473e+09
# 2020-05-15  141619.714286       35535.0         17296531.0   3.036171e+09
# 2020-05-22  151477.857143       36812.0         16672019.0   3.028738e+09
# 2020-05-29  158855.000000       36666.0         14364906.0   3.052802e+09
# 2020-06-05  165648.714286       36610.0         19348983.0   3.067307e+09
# 2020-06-12  172123.142857       37579.0         20087612.0   3.097536e+09
# 2020-06-19  181149.714286       38371.0         21188045.0   3.114677e+09
# 2020-06-26  190360.428571       38821.0         20137021.0   3.141043e+09
# 2020-07-03  199782.714286       39159.0         20908448.0   3.150704e+09
# 2020-07-10  207853.428571       40425.0         21585208.0   3.175933e+09
# 2020-07-17  214940.000000       40229.0         22525159.0   3.192771e+09
# 2020-07-24  221485.571429       42104.0         23232308.0   3.218614e+09
# 2020-07-31  227994.571429       43572.0         24408730.0   3.264349e+09
#
#             ZiyaretciSayisi    TUFE  MerkeziYonetimButceGideri  KonutSatisi
# Tarih
# 2020-03-13         906067.0  450.58                 91161877.0     108670.0
# 2020-03-20         906067.0  450.58                 91161877.0     108670.0
# 2020-03-27         906067.0  450.58                 91161877.0     108670.0
# 2020-04-03          50630.0  454.43                108443227.0      42783.0
# 2020-04-10          50630.0  454.43                108443227.0      42783.0
# 2020-04-17          50630.0  454.43                108443227.0      42783.0
# 2020-04-24          50630.0  454.43                108443227.0      42783.0
# 2020-05-01          51588.0  460.62                 85446203.0      50936.0
# 2020-05-08          51588.0  460.62                 85446203.0      50936.0
# 2020-05-15          51588.0  460.62                 85446203.0      50936.0
# 2020-05-22          51588.0  460.62                 85446203.0      50936.0
# 2020-05-29          51588.0  460.62                 85446203.0      50936.0
# 2020-06-05         128861.0  465.84                 85642670.0     190012.0
# 2020-06-12         128861.0  465.84                 85642670.0     190012.0
# 2020-06-19         128861.0  465.84                 85642670.0     190012.0
# 2020-06-26         128861.0  465.84                 85642670.0     190012.0
# 2020-07-03         128861.0  468.56                116225366.0     229357.0
# 2020-07-10         128861.0  468.56                116225366.0     229357.0
# 2020-07-17         128861.0  468.56                116225366.0     229357.0
# 2020-07-24         128861.0  468.56                116225366.0     229357.0
# 2020-07-31         128861.0  468.56                116225366.0     229357.0

# %% [markdown]
# # Günlük Verilerin Korelasyonu

# %%
daily_corr = daily_merged_data.corr(method="pearson") #Normal dağılmış veri için
#daily_corr = daily_merged_data.corr(method="spearman") #Normal dağılmamış veri için
#daily_corr = daily_merged_data.corr(method="kendall")

daily_corr
# Out:
#                         VakaSayisi  Dolar/TL   Euro/TL  BIST100Kapanis  \
# VakaSayisi                1.000000  0.753411  0.866953        0.878089
# Dolar/TL                  0.753411  1.000000  0.879802        0.435915
# Euro/TL                   0.866953  0.879802  1.000000        0.598495
# BIST100Kapanis            0.878089  0.435915  0.598495        1.000000
# TLGecelikReferansFaizi   -0.319948 -0.034582  0.077072       -0.516124
#
#                         TLGecelikReferansFaizi
# VakaSayisi                           -0.319948
# Dolar/TL                             -0.034582
# Euro/TL                               0.077072
# BIST100Kapanis                       -0.516124
# TLGecelikReferansFaizi                1.000000

# %% [markdown]
# ## Günlük Veri Korelasyonunun Isı Haritası

# %%
sns.heatmap(daily_corr, xticklabels=daily_corr.columns, yticklabels=daily_corr.columns, annot=True)

# %% [markdown]
# # Haftalık Verilerin Korelasyonu

# %%
weelky_corr = weekly_merged_data.corr(method="pearson") #Normal dağılmış veri için
#weelky_corr = weekly_merged_data.corr(method="spearman") #Normal dağılmamış veri için
#weelky_corr = weekly_merged_data.corr(method="kendall")

weelky_corr
# Out:
#                            VakaSayisi  AltinRezervi  KartHarcamaTutari  \
# VakaSayisi                   1.000000      0.953133           0.617298
# AltinRezervi                 0.953133      1.000000           0.673037
# KartHarcamaTutari            0.617298      0.673037           1.000000
# HaftalikKredi                0.991646      0.957231           0.600060
# ZiyaretciSayisi             -0.594059     -0.526965           0.087361
# TUFE                         0.970299      0.934822           0.676146
# MerkeziYonetimButceGideri    0.194979      0.362157           0.266054
# KonutSatisi                  0.674894      0.728564           0.874059
#
#                            HaftalikKredi  ZiyaretciSayisi      TUFE  \
# VakaSayisi                      0.991646        -0.594059  0.970299
# AltinRezervi                    0.957231        -0.526965  0.934822
# KartHarcamaTutari               0.600060         0.087361  0.676146
# HaftalikKredi                   1.000000        -0.618998  0.965656
# ZiyaretciSayisi                -0.618998         1.000000 -0.560656
# TUFE                            0.965656        -0.560656  1.000000
# MerkeziYonetimButceGideri       0.249496        -0.180756  0.231024
# KonutSatisi                     0.665813         0.029094  0.760530
#
#                            MerkeziYonetimButceGideri  KonutSatisi
# VakaSayisi                                  0.194979     0.674894
# AltinRezervi                                0.362157     0.728564
# KartHarcamaTutari                           0.266054     0.874059
# HaftalikKredi                               0.249496     0.665813
# ZiyaretciSayisi                            -0.180756     0.029094
# TUFE                                        0.231024     0.760530
# MerkeziYonetimButceGideri                   1.000000     0.365703
# KonutSatisi                                 0.365703     1.000000

# %% [markdown]
# ## Haftalık Veri Korelasyonunun Isı Haritası

# %%
sns.heatmap(weelky_corr, xticklabels=weelky_corr.columns, yticklabels=weelky_corr.columns, annot=True)

# %%
case_plot = plt.gca()
daily_merged_data.plot(kind='line', y='VakaSayisi', color='red', ax=case_plot, use_index=True)
case_plot.set_xlabel("Tarih")
case_plot.set_ylabel("Vaka Sayısı")
case_plot

# %%
cbrt_plot = plt.gca()
daily_merged_data.plot(kind='line', y="Dolar/TL", color='green', ax=cbrt_plot, use_index=True)
daily_merged_data.plot(kind='line', y="Euro/TL", color='blue', ax=cbrt_plot, use_index=True)
cbrt_plot.set_xlabel("Tarih")
cbrt_plot.set_ylabel("Günlük Kur")
cbrt_plot
